# %%
# %pip install -q -U google-generativeai
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# load environmental variables into nb
from dotenv import load_dotenv
load_dotenv()
import os
from pinecone import Pinecone, ServerlessSpec
# import the Python SDK
import google.generativeai as genai
# retrieve the API key from the environment
GEMINI_API_KEY = os.getenv('GEMINI_API_KEY')
# configure the Gemini API using the retrieved key
genai.configure(api_key=GEMINI_API_KEY)

# %%
# retrieve the API key from the environment
pc = Pinecone(api_key = os.getenv("PINECONE_API_KEY"))
# create pinecone index
pc.create_index(
    name="rag", 
    dimension=768,  # gemini text embedding model supports up to 768 dimensions (length of the document embedding vector is 768)
    metric="cosine",  # used for semantic search
    spec=ServerlessSpec(
        cloud="aws",
        region="us-east-1"
    )
)
# Out:
# ---------------------------------------------------------------------------
# PineconeApiException                      Traceback (most recent call last)
# Cell In[7], line 4
#       2 pc = Pinecone(api_key = os.getenv("PINECONE_API_KEY"))
#       3 # create pinecone index
# ----> 4 pc.create_index(
#       5     name="rag",
#       6     dimension=768,  # gemini text embedding model supports up to 768 dimensions (length of the document embedding vector is 768)
#       7     metric="cosine",  # used for semantic search
#       8     spec=ServerlessSpec(
#       9         cloud="aws",
#      10         region="us-east-1"
#      11     )
#      12 )
#
# File /opt/miniconda3/envs/rag/lib/python3.10/site-packages/pinecone/control/pinecone.py:384, in Pinecone.create_index(self, name, dimension, spec, metric, timeout, deletion_protection)
#     381 else:
#     382     raise TypeError("spec must be of type dict, ServerlessSpec, or PodSpec")
# --> 384 api_instance.create_index(
#     385     create_index_request=CreateIndexRequest(
#     386         name=name,
#     387         dimension=dimension,
#     388         metric=metric,
#     389         spec=index_spec,
#     390         deletion_protection=dp,
#     391     ),
#     392 )
#     394 def is_ready():
#     395     status = self._get_status(name)
#
# File /opt/miniconda3/envs/rag/lib/python3.10/site-packages/pinecone/core/openapi/shared/api_client.py:761, in Endpoint.__call__(self, *args, **kwargs)
#     750 def __call__(self, *args, **kwargs):
#     751     """This method is invoked when endpoints are called
#     752     Example:
#     753
#    (...)
#     759
#     760     """
# --> 761     return self.callable(self, *args, **kwargs)
#
# File /opt/miniconda3/envs/rag/lib/python3.10/site-packages/pinecone/core/openapi/control/api/manage_indexes_api.py:273, in ManageIndexesApi.__init__.<locals>.__create_index(self, create_index_request, **kwargs)
#     271 kwargs["_host_index"] = kwargs.get("_host_index")
#     272 kwargs["create_index_request"] = create_index_request
# --> 273 return self.call_with_http_info(**kwargs)
#
# File /opt/miniconda3/envs/rag/lib/python3.10/site-packages/pinecone/core/openapi/shared/api_client.py:819, in Endpoint.call_with_http_info(self, **kwargs)
#     816     header_list = self.api_client.select_header_content_type(content_type_headers_list)
#     817     params["header"]["Content-Type"] = header_list
# --> 819 return self.api_client.call_api(
#     820     self.settings["endpoint_path"],
#     821     self.settings["http_method"],
#     822     params["path"],
#     823     params["query"],
#     824     params["header"],
#     825     body=params["body"],
#     826     post_params=params["form"],
#     827     files=params["file"],
#     828     response_type=self.settings["response_type"],
#     829     auth_settings=self.settings["auth"],
#     830     async_req=kwargs["async_req"],
#     831     _check_type=kwargs["_check_return_type"],
#     832     _return_http_data_only=kwargs["_return_http_data_only"],
#     833     _preload_content=kwargs["_preload_content"],
#     834     _request_timeout=kwargs["_request_timeout"],
#     835     _host=_host,
#     836     collection_formats=params["collection_format"],
#     837 )
#
# File /opt/miniconda3/envs/rag/lib/python3.10/site-packages/pinecone/core/openapi/shared/api_client.py:380, in ApiClient.call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_req, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     326 """Makes the HTTP request (synchronous) and returns deserialized data.
#     327
#     328 To make an async_req request, set the async_req parameter.
#    (...)
#     377     then the method will return the response directly.
#     378 """
#     379 if not async_req:
# --> 380     return self.__call_api(
#     381         resource_path,
#     382         method,
#     383         path_params,
#     384         query_params,
#     385         header_params,
#     386         body,
#     387         post_params,
#     388         files,
#     389         response_type,
#     390         auth_settings,
#     391         _return_http_data_only,
#     392         collection_formats,
#     393         _preload_content,
#     394         _request_timeout,
#     395         _host,
#     396         _check_type,
#     397     )
#     399 return self.pool.apply_async(
#     400     self.__call_api,
#     401     (
#    (...)
#     418     ),
#     419 )
#
# File /opt/miniconda3/envs/rag/lib/python3.10/site-packages/pinecone/core/openapi/shared/api_client.py:187, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     185 except PineconeApiException as e:
#     186     e.body = e.body.decode("utf-8")
# --> 187     raise e
#     189 self.last_response = response_data
#     191 return_data = response_data
#
# File /opt/miniconda3/envs/rag/lib/python3.10/site-packages/pinecone/core/openapi/shared/api_client.py:175, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     171     url = _host + resource_path
#     173 try:
#     174     # perform request and return response
# --> 175     response_data = self.request(
#     176         method,
#     177         url,
#     178         query_params=query_params,
#     179         headers=header_params,
#     180         post_params=post_params,
#     181         body=body,
#     182         _preload_content=_preload_content,
#     183         _request_timeout=_request_timeout,
#     184     )
#     185 except PineconeApiException as e:
#     186     e.body = e.body.decode("utf-8")
#
# File /opt/miniconda3/envs/rag/lib/python3.10/site-packages/pinecone/core/openapi/shared/api_client.py:460, in ApiClient.request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     450     return self.rest_client.OPTIONS(
#     451         url,
#     452         query_params=query_params,
#    (...)
#     457         body=body,
#     458     )
#     459 elif method == "POST":
# --> 460     return self.rest_client.POST(
#     461         url,
#     462         query_params=query_params,
#     463         headers=headers,
#     464         post_params=post_params,
#     465         _preload_content=_preload_content,
#     466         _request_timeout=_request_timeout,
#     467         body=body,
#     468     )
#     469 elif method == "PUT":
#     470     return self.rest_client.PUT(
#     471         url,
#     472         query_params=query_params,
#    (...)
#     477         body=body,
#     478     )
#
# File /opt/miniconda3/envs/rag/lib/python3.10/site-packages/pinecone/core/openapi/shared/rest.py:345, in RESTClientObject.POST(self, url, headers, query_params, post_params, body, _preload_content, _request_timeout)
#     335 def POST(
#     336     self,
#     337     url,
#    (...)
#     343     _request_timeout=None,
#     344 ):
# --> 345     return self.request(
#     346         "POST",
#     347         url,
#     348         headers=headers,
#     349         query_params=query_params,
#     350         post_params=post_params,
#     351         _preload_content=_preload_content,
#     352         _request_timeout=_request_timeout,
#     353         body=body,
#     354     )
#
# File /opt/miniconda3/envs/rag/lib/python3.10/site-packages/pinecone/core/openapi/shared/rest.py:279, in RESTClientObject.request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     276     if 500 <= r.status <= 599:
#     277         raise ServiceException(http_resp=r)
# --> 279     raise PineconeApiException(http_resp=r)
#     281 return r
#
# PineconeApiException: (409)
# Reason: Conflict
# HTTP response headers: HTTPHeaderDict({'content-type': 'text/plain; charset=utf-8', 'access-control-allow-origin': '*', 'vary': 'origin,access-control-request-method,access-control-request-headers', 'access-control-expose-headers': '*', 'x-pinecone-api-version': '2024-07', 'X-Cloud-Trace-Context': 'd77316014d3ec28e9a48cbf13c2d2b39', 'Date': 'Sun, 25 Aug 2024 18:53:11 GMT', 'Server': 'Google Frontend', 'Content-Length': '85', 'Via': '1.1 google', 'Alt-Svc': 'h3=":443"; ma=2592000,h3-29=":443"; ma=2592000'})
# HTTP response body: {"error":{"code":"ALREADY_EXISTS","message":"Resource  already exists"},"status":409}

# %%
import json
data = json.load(open("reviews.json"))
data['reviews']
# Out:
# [{'professorName': 'Dr. Sarah Johnson',
#   'course': 'Introduction to Psychology',
#   'rating': 4,
#   'review': 'Dr. Johnson is very knowledgeable and makes the class engaging. Her examples are relatable and help in understanding complex concepts.'},
#  {'professorName': 'Prof. Michael Chen',
#   'course': 'Advanced Calculus',
#   'rating': 5,
#   'review': "Professor Chen is exceptional! His explanations are clear, and he's always willing to help during office hours. Challenging but rewarding course."},
#  {'professorName': 'Dr. Emily Rodriguez',
#   'course': 'World History',
#   'rating': 3,
#   'review': "The course content is interesting, but Dr. Rodriguez's lectures can be a bit dry. More interactive elements would improve the class."},
#  {'professorName': 'Prof. David Thompson',
#   'course': 'Organic Chemistry',
#   'rating': 4,
#   'review': 'Tough course, but Prof. Thompson makes it manageable. His practice problems are especially helpful for exam preparation.'},
#  {'professorName': 'Dr. Lisa Patel',
#   'course': 'Introduction to Sociology',
#   'rating': 5,
#   'review': 'Dr. Patel is passionate about the subject and it shows. Her classes are thought-provoking and encourage critical thinking.'},
#  {'professorName': 'Prof. Robert Wilson',
#   'course': 'Macroeconomics',
#   'rating': 2,
#   'review': "The course material is important, but Prof. Wilson's teaching style is confusing. Often leaves students more puzzled than enlightened."},
#  {'professorName': 'Dr. Jennifer Lee',
#   'course': 'Molecular Biology',
#   'rating': 4,
#   'review': 'Dr. Lee is very knowledgeable and provides great real-world applications. The lab work is particularly informative.'},
#  {'professorName': 'Prof. Thomas Brown',
#   'course': 'Classical Literature',
#   'rating': 3,
#   'review': 'Prof. Brown clearly knows his stuff, but his lectures can be long-winded. The reading list is excellent though.'},
#  {'professorName': 'Dr. Olivia Martinez',
#   'course': 'Environmental Science',
#   'rating': 5,
#   'review': 'Dr. Martinez is inspirational! Her passion for the environment is contagious, and she organizes great field trips.'},
#  {'professorName': 'Prof. Andrew Kim',
#   'course': 'Linear Algebra',
#   'rating': 4,
#   'review': 'Prof. Kim explains complex concepts clearly. His problem sets are challenging but greatly improve understanding.'},
#  {'professorName': 'Dr. Rachel Green',
#   'course': 'Abnormal Psychology',
#   'rating': 5,
#   'review': "Dr. Green brings the subject to life with case studies and guest speakers. One of the best courses I've taken."},
#  {'professorName': 'Prof. James Clark',
#   'course': 'American Literature',
#   'rating': 2,
#   'review': "The course readings are interesting, but Prof. Clark's lectures lack enthusiasm. More class discussions would be beneficial."},
#  {'professorName': 'Dr. Maria Sanchez',
#   'course': 'Quantum Physics',
#   'rating': 4,
#   'review': 'Dr. Sanchez tackles this difficult subject with clarity. Her problem-solving approach is particularly helpful.'},
#  {'professorName': 'Prof. William Taylor',
#   'course': 'Marketing Principles',
#   'rating': 3,
#   'review': 'Prof. Taylor has good industry insights, but the course structure could be improved. More practical projects would be useful.'},
#  {'professorName': 'Dr. Karen White',
#   'course': 'Human Anatomy',
#   'rating': 5,
#   'review': "Dr. White's teaching methods are excellent. The lab sessions are particularly informative and well-organized."},
#  {'professorName': 'Prof. Daniel Lee',
#   'course': 'International Relations',
#   'rating': 4,
#   'review': 'Prof. Lee brings a wealth of experience to the class. His lectures are engaging and provide great insights into global politics.'},
#  {'professorName': 'Dr. Sophia Anderson',
#   'course': 'Organic Chemistry',
#   'rating': 2,
#   'review': 'Dr. Anderson seems knowledgeable, but her explanations are often confusing. More practice problems would be helpful.'},
#  {'professorName': 'Prof. Christopher Moore',
#   'course': 'Computer Science Fundamentals',
#   'rating': 5,
#   'review': 'Prof. Moore is an outstanding teacher. His coding examples and projects are practical and really enhance learning.'},
#  {'professorName': 'Dr. Elizabeth Turner',
#   'course': 'Art History',
#   'rating': 3,
#   'review': 'Dr. Turner is passionate about art, but her lectures can be overwhelming. More visual aids would improve the class experience.'},
#  {'professorName': 'Prof. Jeffrey Adams',
#   'course': 'Business Ethics',
#   'rating': 4,
#   'review': 'Prof. Adams facilitates great class discussions on complex ethical issues. The case studies are particularly thought-provoking.'}]

# %%
processed_data = []

for review in data["reviews"]:
    # generate embedding
    response = genai.embed_content(
        model="models/text-embedding-004",
        content=review['review']
    )
    embedding = response['embedding']
    
    # add to the processed data
    processed_data.append({
        "values": embedding,
        "id": review["professorName"],
        "metadata": {
            "review": review["review"],
            "course": review["course"],
            "rating": review["rating"]
        }
    })

# %%
len(processed_data[0]['values'])
processed_data[19]
# Out:
# {'values': [0.08200847,
#   0.012068306,
#   -0.027874943,
#   0.010626679,
#   -0.03337673,
#   -0.006424036,
#   -0.031818718,
#   0.02154729,
#   0.018877499,
#   0.029667746,
#   0.05627522,
#   0.022060944,
#   0.02643932,
#   0.0037484397,
#   -0.0008335538,
#   -0.014432067,
#   0.029483806,
#   0.0006963744,
#   -0.04219324,
#   0.011367902,
#   0.032126654,
#   -0.015777241,
#   0.015773168,
#   -0.022171846,
#   0.014752186,
#   -0.013767421,
#   -0.0064005475,
#   -0.018016031,
#   0.033082124,
#   -0.028021075,
#   0.048203643,
#   0.04166721,
#   -0.009751196,
#   -0.07281184,
#   -0.03652561,
#   0.0023495015,
#   -0.00940853,
#   -0.0147644915,
#   -0.030199973,
#   -0.07008442,
#   -0.016028775,
#   0.01991008,
#   -0.028893145,
#   0.026235146,
#   -0.04129293,
#   0.036412135,
#   -0.028693464,
#   0.08735985,
#   -0.04599868,
#   0.091042556,
#   0.014021267,
#   0.07767947,
#   -0.04563229,
#   0.024540069,
#   -0.036789283,
#   -0.011906124,
#   -0.020014297,
#   -0.080087036,
#   0.024822526,
#   -0.021503178,
#   -0.017287845,
#   -0.04080307,
#   -0.026207043,
#   -0.0582928,
#   0.091167696,
#   -0.03753349,
#   -0.044382744,
#   -0.05294686,
#   -0.02356487,
#   0.052997917,
#   0.014941916,
#   -0.004918032,
#   0.041997578,
#   0.02148997,
#   0.0042892923,
#   -0.041383523,
#   -0.025578093,
#   0.02377259,
#   0.017925993,
#   0.023981974,
#   0.019847905,
#   0.005445907,
#   0.07949943,
#   0.04028992,
#   -0.02566584,
#   0.009812146,
#   0.006917774,
#   -0.03552275,
#   0.008741975,
#   -0.040158734,
#   0.004458219,
#   0.031530064,
#   0.013060276,
#   0.010491075,
#   -0.023598654,
#   0.0612888,
#   -0.047418684,
#   0.03653652,
#   0.05940707,
#   0.0442168,
#   -0.019785559,
#   0.024312187,
#   0.0065663885,
#   -0.012238602,
#   0.0015821743,
#   0.054194435,
#   0.056594163,
#   -0.0039743306,
#   -0.014012677,
#   0.10997795,
#   -0.04798617,
#   -0.005374149,
#   -0.013463101,
#   -0.026543204,
#   0.026297322,
#   0.00491132,
#   -0.04332368,
#   0.049774416,
#   -0.0032300157,
#   -0.005915123,
#   0.038722873,
#   -0.039688267,
#   -0.056096043,
#   0.09280111,
#   0.08217664,
#   0.024753263,
#   -0.04492002,
#   0.05400601,
#   0.0033322794,
#   -0.0003980166,
#   -0.01832239,
#   -0.045719564,
#   0.035379574,
#   -0.028476989,
#   -0.03463111,
#   -0.0064364066,
#   0.06470909,
#   0.04472165,
#   0.008306571,
#   -0.028288808,
#   -0.0025793235,
#   0.024867157,
#   -0.04271657,
#   0.027747793,
#   -0.010473665,
#   -0.045547847,
#   0.03426086,
#   0.04428763,
#   -0.01075006,
#   0.00093026727,
#   0.0107508125,
#   0.03215976,
#   -0.0145147545,
#   -0.03915527,
#   -0.02501979,
#   -0.053053617,
#   -0.003149822,
#   -0.015781397,
#   0.04755684,
#   -0.001869712,
#   -0.0036762338,
#   0.015570671,
#   -0.034565013,
#   0.048695706,
#   -0.027303686,
#   0.052456018,
#   -0.04200654,
#   0.022668445,
#   -0.011030939,
#   -0.008143271,
#   -0.048597645,
#   -0.006449928,
#   -0.030898431,
#   -0.07292907,
#   0.05880545,
#   0.014271177,
#   -0.074038066,
#   0.0030674646,
#   0.014925558,
#   -0.0051266467,
#   0.048188083,
#   0.021534467,
#   -0.011519864,
#   -0.0082641775,
#   0.04781584,
#   0.044220075,
#   -0.004664026,
#   0.025353324,
#   -0.00938181,
#   -0.04282359,
#   -0.038014367,
#   -0.0047301957,
#   -0.0011838187,
#   0.05789014,
#   -0.04553192,
#   0.077847786,
#   0.052765727,
#   0.029459715,
#   -0.025106281,
#   -0.012548878,
#   -0.068673335,
#   0.04746988,
#   -0.04008485,
#   0.04566856,
#   -0.006111264,
#   0.0016191559,
#   -0.000521259,
#   0.032444432,
#   -0.05270443,
#   0.022081442,
#   0.07038587,
#   -0.03985738,
#   -0.031217335,
#   0.007949163,
#   -0.019927565,
#   -0.007492356,
#   -0.03466558,
#   -0.03587561,
#   -0.024376862,
#   -0.036250435,
#   0.05223457,
#   0.058056243,
#   0.01784063,
#   0.026371257,
#   -0.050541542,
#   0.014103786,
#   -0.031711627,
#   0.012454092,
#   0.055214033,
#   -0.003619743,
#   -0.016134584,
#   -0.02343979,
#   -0.053290617,
#   -0.05573949,
#   0.0040085134,
#   -0.05107595,
#   -0.01603067,
#   -0.023026101,
#   -0.036724202,
#   -0.03485239,
#   0.0021568087,
#   -0.0016052026,
#   -1.9756837e-05,
#   0.025717221,
#   -0.037990697,
#   -0.0023507194,
#   0.01222559,
#   -0.038327023,
#   -0.07074813,
#   -0.0009791033,
#   -0.020863153,
#   0.028605092,
#   0.025713434,
#   -0.042157743,
#   0.040423736,
#   -0.018187545,
#   0.03310619,
#   -0.01850745,
#   -0.061193947,
#   0.008953818,
#   0.0017108339,
#   -0.0055951634,
#   -0.047849588,
#   -0.030600905,
#   0.06408867,
#   0.013079847],
#  'id': 'Prof. Jeffrey Adams',
#  'metadata': {'review': 'Prof. Adams facilitates great class discussions on complex ethical issues. The case studies are particularly thought-provoking.',
#   'course': 'Business Ethics',
#   'rating': 4}}

# %%
index = pc.Index('rag')  # index is a collection in firebase
index.upsert(
    vectors=processed_data,
    namespace="ns1"  # namespace is a document in firebase
)
# Out:
# {'upserted_count': 20}

# %%
index.describe_index_stats()
# Out:
# {'dimension': 768,
#  'index_fullness': 0.0,
#  'namespaces': {'ns1': {'vector_count': 20}},
#  'total_vector_count': 20}
